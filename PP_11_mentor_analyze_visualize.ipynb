# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Out:
# --2024-12-10 13:54:39--  https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133023 (130K) [text/plain]
# Saving to: ‘student_data.csv’
#
# student_data.csv    100%[===================>] 129.91K  --.-KB/s    in 0.02s
#
# 2024-12-10 13:54:39 (8.08 MB/s) - ‘student_data.csv’ saved [133023/133023]

# %%
#import titanic database from drive
df = pd.read_csv("student_data.csv")
df.head()
df.sample(5)
# Out:
#       id first_name last_name                            email  gender  \
# 970  971     Rafael   Speedin              rspeedinqy@noaa.gov    Male
# 674  675      Dayle  McKenney            dmckenneyiq@phpbb.com  Female
# 124  125  Aristotle  Treneman         atreneman3g@symantec.com    Male
# 966  967    Mabelle   Melross  mmelrossqu@networksolutions.com  Female
# 800  801       Edna     Flawn         eflawnm8@nydailynews.com  Female
#
#          ip_address  cgpa  passing_year        department  attendance  \
# 970   184.53.52.197  1.63        2003.0  Computer Science       69.05
# 674   238.98.138.33  2.56        2015.0  Computer Science       39.45
# 124   116.102.4.194  1.95        2013.0  Computer Science       96.46
# 966   24.88.172.182  3.85        2017.0          Business       32.65
# 800  159.104.61.127  3.44        2023.0  Computer Science       96.11
#
#     home_district  abroad_study  student_id  graduation_date  \
# 970       Houston         False         971             2017
# 674       Houston         False         675             2015
# 124   Los Angeles         False         125             2014
# 966       Chicago         False         967             2003
# 800       Houston         False         801             2011
#
#     study_abroad_country       study_abroad_city  hsc_gpa  ssc_gpa
# 970                China                   Yi’an        3        1
# 674               Taiwan                  Zhubei        4        4
# 124                Japan                     Iyo        3        2
# 966            Guatemala  Palestina de los Altos        2        1
# 800               France                Paris 16        3        2
